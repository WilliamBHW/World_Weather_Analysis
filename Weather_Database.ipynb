# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
def lat(size):
    lat = []
    x = 0
    while x < (size):
        random_lat = random.randint(-90, 90) + random.random()
        lat.append(random_lat)
        x += 1
    return lat
def lng(size):
    lng = []
    y = 0
    while y < (size):
        random_lng = random.randint(-180, 180) + random.random()
        lng.append(random_lng)
        y += 1
    return lng

# %%
lat = lat(2000)
lng = lng(2000)
lat_lngs = zip(lat, lng)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 744

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | tasiilaq
# Processing Record 3 of Set 1 | tateyama
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | ossora
# Processing Record 6 of Set 1 | omboue
# Processing Record 7 of Set 1 | tirat karmel
# Processing Record 8 of Set 1 | tuktoyaktuk
# Processing Record 9 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 1 | mutoko
# Processing Record 11 of Set 1 | hobart
# Processing Record 12 of Set 1 | bambous virieux
# Processing Record 13 of Set 1 | talnakh
# Processing Record 14 of Set 1 | chokurdakh
# Processing Record 15 of Set 1 | manakara
# Processing Record 16 of Set 1 | grand gaube
# Processing Record 17 of Set 1 | lebu
# Processing Record 18 of Set 1 | butterworth
# Processing Record 19 of Set 1 | volksrust
# Processing Record 20 of Set 1 | badarpur
# Processing Record 21 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 22 of Set 1 | muros
# Processing Record 23 of Set 1 | roald
# Processing Record 24 of Set 1 | bredasdorp
# Processing Record 25 of Set 1 | mataura
# Processing Record 26 of Set 1 | kapaa
# Processing Record 27 of Set 1 | hamilton
# Processing Record 28 of Set 1 | cape town
# Processing Record 29 of Set 1 | faanui
# Processing Record 30 of Set 1 | jamestown
# Processing Record 31 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 1 | cap malheureux
# Processing Record 33 of Set 1 | meadow lake
# Processing Record 34 of Set 1 | souillac
# Processing Record 35 of Set 1 | guerrero negro
# Processing Record 36 of Set 1 | brazzaville
# Processing Record 37 of Set 1 | busselton
# Processing Record 38 of Set 1 | bluff
# Processing Record 39 of Set 1 | hermanus
# Processing Record 40 of Set 1 | fortuna
# Processing Record 41 of Set 1 | naze
# Processing Record 42 of Set 1 | saskylakh
# Processing Record 43 of Set 1 | port alfred
# Processing Record 44 of Set 1 | gat
# Processing Record 45 of Set 1 | kununurra
# Processing Record 46 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 1 | albany
# Processing Record 48 of Set 1 | sambava
# Processing Record 49 of Set 1 | saint-philippe
# Processing Record 50 of Set 1 | avarua
# Processing Record 1 of Set 2 | qaanaaq
# Processing Record 2 of Set 2 | luderitz
# Processing Record 3 of Set 2 | mangan
# Processing Record 4 of Set 2 | new norfolk
# Processing Record 5 of Set 2 | pinega
# Processing Record 6 of Set 2 | east london
# Processing Record 7 of Set 2 | beringovskiy
# Processing Record 8 of Set 2 | vaini
# Processing Record 9 of Set 2 | tselinnoye
# Processing Record 10 of Set 2 | bacuit
# City not found. Skipping...
# Processing Record 11 of Set 2 | uglovskoye
# Processing Record 12 of Set 2 | susangerd
# Processing Record 13 of Set 2 | san ignacio
# Processing Record 14 of Set 2 | lata
# Processing Record 15 of Set 2 | hilo
# Processing Record 16 of Set 2 | san cristobal
# Processing Record 17 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 18 of Set 2 | hirara
# Processing Record 19 of Set 2 | airai
# Processing Record 20 of Set 2 | skagastrond
# City not found. Skipping...
# Processing Record 21 of Set 2 | tabuk
# Processing Record 22 of Set 2 | atuona
# Processing Record 23 of Set 2 | severo-yeniseyskiy
# Processing Record 24 of Set 2 | leningradskiy
# Processing Record 25 of Set 2 | nurota
# Processing Record 26 of Set 2 | yellowknife
# Processing Record 27 of Set 2 | qaqortoq
# Processing Record 28 of Set 2 | meulaboh
# Processing Record 29 of Set 2 | peniche
# Processing Record 30 of Set 2 | barrow
# Processing Record 31 of Set 2 | nuuk
# Processing Record 32 of Set 2 | mar del plata
# Processing Record 33 of Set 2 | olafsvik
# Processing Record 34 of Set 2 | shingu
# Processing Record 35 of Set 2 | ribeira grande
# Processing Record 36 of Set 2 | ostrovnoy
# Processing Record 37 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 2 | tuatapere
# Processing Record 39 of Set 2 | koumac
# Processing Record 40 of Set 2 | saint george
# Processing Record 41 of Set 2 | san rafael
# Processing Record 42 of Set 2 | filingue
# Processing Record 43 of Set 2 | castro
# Processing Record 44 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 45 of Set 2 | whitehorse
# Processing Record 46 of Set 2 | bethel
# Processing Record 47 of Set 2 | carnarvon
# Processing Record 48 of Set 2 | puerto ayora
# Processing Record 49 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 50 of Set 2 | punta arenas
# Processing Record 1 of Set 3 | uptar
# Processing Record 2 of Set 3 | sitka
# Processing Record 3 of Set 3 | maltahohe
# Processing Record 4 of Set 3 | pundaguitan
# Processing Record 5 of Set 3 | thompson
# Processing Record 6 of Set 3 | alofi
# Processing Record 7 of Set 3 | iracoubo
# Processing Record 8 of Set 3 | butaritari
# Processing Record 9 of Set 3 | port hardy
# Processing Record 10 of Set 3 | port lincoln
# Processing Record 11 of Set 3 | evensk
# Processing Record 12 of Set 3 | oranjestad
# Processing Record 13 of Set 3 | arraial do cabo
# Processing Record 14 of Set 3 | semporna
# Processing Record 15 of Set 3 | luzhou
# Processing Record 16 of Set 3 | algiers
# Processing Record 17 of Set 3 | marsa matruh
# Processing Record 18 of Set 3 | half moon bay
# Processing Record 19 of Set 3 | mahebourg
# Processing Record 20 of Set 3 | along
# Processing Record 21 of Set 3 | caceres
# Processing Record 22 of Set 3 | georgetown
# Processing Record 23 of Set 3 | maceio
# Processing Record 24 of Set 3 | torbay
# Processing Record 25 of Set 3 | tura
# Processing Record 26 of Set 3 | mogadishu
# Processing Record 27 of Set 3 | varnsdorf
# Processing Record 28 of Set 3 | pevek
# Processing Record 29 of Set 3 | dikson
# Processing Record 30 of Set 3 | okhotsk
# Processing Record 31 of Set 3 | port blair
# Processing Record 32 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 33 of Set 3 | nueva loja
# Processing Record 34 of Set 3 | cabo san lucas
# Processing Record 35 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 36 of Set 3 | upernavik
# Processing Record 37 of Set 3 | balkhash
# Processing Record 38 of Set 3 | prince rupert
# Processing Record 39 of Set 3 | amancio
# City not found. Skipping...
# Processing Record 40 of Set 3 | pecos
# Processing Record 41 of Set 3 | provideniya
# Processing Record 42 of Set 3 | lagunas
# Processing Record 43 of Set 3 | mouila
# Processing Record 44 of Set 3 | vao
# Processing Record 45 of Set 3 | lorengau
# Processing Record 46 of Set 3 | adrar
# Processing Record 47 of Set 3 | klaksvik
# Processing Record 48 of Set 3 | hithadhoo
# Processing Record 49 of Set 3 | inhambane
# Processing Record 50 of Set 3 | zimmi
# Processing Record 1 of Set 4 | zhezkazgan
# Processing Record 2 of Set 4 | malwan
# City not found. Skipping...
# Processing Record 3 of Set 4 | alasehir
# Processing Record 4 of Set 4 | behshahr
# Processing Record 5 of Set 4 | fryanovo
# Processing Record 6 of Set 4 | yamada
# Processing Record 7 of Set 4 | alice springs
# Processing Record 8 of Set 4 | madison
# Processing Record 9 of Set 4 | avera
# Processing Record 10 of Set 4 | monywa
# Processing Record 11 of Set 4 | mastic beach
# Processing Record 12 of Set 4 | vila franca do campo
# Processing Record 13 of Set 4 | sarakhs
# Processing Record 14 of Set 4 | esmeraldas
# Processing Record 15 of Set 4 | bengkulu
# Processing Record 16 of Set 4 | usinsk
# Processing Record 17 of Set 4 | broome
# Processing Record 18 of Set 4 | satitoa
# City not found. Skipping...
# Processing Record 19 of Set 4 | newport
# Processing Record 20 of Set 4 | taltal
# Processing Record 21 of Set 4 | kondinskoye
# Processing Record 22 of Set 4 | narsaq
# Processing Record 23 of Set 4 | goderich
# Processing Record 24 of Set 4 | znamenskoye
# Processing Record 25 of Set 4 | saint-augustin
# Processing Record 26 of Set 4 | severo-kurilsk
# Processing Record 27 of Set 4 | moose factory
# Processing Record 28 of Set 4 | vila velha
# Processing Record 29 of Set 4 | chulman
# Processing Record 30 of Set 4 | cockburn harbour
# City not found. Skipping...
# Processing Record 31 of Set 4 | port elizabeth
# Processing Record 32 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 33 of Set 4 | paamiut
# Processing Record 34 of Set 4 | yurimaguas
# Processing Record 35 of Set 4 | bushenyi
# Processing Record 36 of Set 4 | zhanaozen
# Processing Record 37 of Set 4 | gunjur
# Processing Record 38 of Set 4 | ravar
# Processing Record 39 of Set 4 | krasnovishersk
# Processing Record 40 of Set 4 | guangyuan
# Processing Record 41 of Set 4 | kavaratti
# Processing Record 42 of Set 4 | kildinstroy
# Processing Record 43 of Set 4 | tiarei
# Processing Record 44 of Set 4 | hasaki
# Processing Record 45 of Set 4 | warrenton
# Processing Record 46 of Set 4 | teluknaga
# Processing Record 47 of Set 4 | concepcion de buenos aires
# Processing Record 48 of Set 4 | stawell
# Processing Record 49 of Set 4 | hambantota
# Processing Record 50 of Set 4 | wilmington island
# Processing Record 1 of Set 5 | bosaso
# Processing Record 2 of Set 5 | puerto del rosario
# Processing Record 3 of Set 5 | victor harbor
# Processing Record 4 of Set 5 | solnechnyy
# Processing Record 5 of Set 5 | maralal
# Processing Record 6 of Set 5 | olavarria
# Processing Record 7 of Set 5 | buala
# Processing Record 8 of Set 5 | cherskiy
# Processing Record 9 of Set 5 | bathsheba
# Processing Record 10 of Set 5 | mentok
# City not found. Skipping...
# Processing Record 11 of Set 5 | sarkand
# Processing Record 12 of Set 5 | srednekolymsk
# Processing Record 13 of Set 5 | hovd
# Processing Record 14 of Set 5 | deputatskiy
# Processing Record 15 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 5 | lagoa
# Processing Record 17 of Set 5 | neuquen
# Processing Record 18 of Set 5 | sorland
# Processing Record 19 of Set 5 | nikolskoye
# Processing Record 20 of Set 5 | tyrma
# Processing Record 21 of Set 5 | kinablangan
# Processing Record 22 of Set 5 | zheshart
# Processing Record 23 of Set 5 | baijiantan
# Processing Record 24 of Set 5 | saqqez
# Processing Record 25 of Set 5 | dudinka
# Processing Record 26 of Set 5 | clyde river
# Processing Record 27 of Set 5 | sungairaya
# Processing Record 28 of Set 5 | vieques
# Processing Record 29 of Set 5 | mount gambier
# Processing Record 30 of Set 5 | chuy
# Processing Record 31 of Set 5 | trairi
# Processing Record 32 of Set 5 | yumen
# Processing Record 33 of Set 5 | buqayq
# City not found. Skipping...
# Processing Record 34 of Set 5 | mattru
# Processing Record 35 of Set 5 | lodwar
# Processing Record 36 of Set 5 | tam ky
# Processing Record 37 of Set 5 | san isidro
# Processing Record 38 of Set 5 | huangpi
# Processing Record 39 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 40 of Set 5 | pafos
# Processing Record 41 of Set 5 | ivankiv
# Processing Record 42 of Set 5 | pochutla
# Processing Record 43 of Set 5 | mayo
# Processing Record 44 of Set 5 | brindisi
# Processing Record 45 of Set 5 | los llanos de aridane
# Processing Record 46 of Set 5 | sinnamary
# Processing Record 47 of Set 5 | timra
# Processing Record 48 of Set 5 | sibolga
# Processing Record 49 of Set 5 | kudymkar
# Processing Record 50 of Set 5 | lokosovo
# Processing Record 1 of Set 6 | yar-sale
# Processing Record 2 of Set 6 | parabel
# Processing Record 3 of Set 6 | hobyo
# Processing Record 4 of Set 6 | sindor
# Processing Record 5 of Set 6 | gudari
# Processing Record 6 of Set 6 | jamsa
# Processing Record 7 of Set 6 | tiksi
# Processing Record 8 of Set 6 | sola
# Processing Record 9 of Set 6 | chippewa falls
# Processing Record 10 of Set 6 | mana
# Processing Record 11 of Set 6 | bandarbeyla
# Processing Record 12 of Set 6 | toribio
# Processing Record 13 of Set 6 | salinas
# Processing Record 14 of Set 6 | sterling
# Processing Record 15 of Set 6 | saint-joseph
# Processing Record 16 of Set 6 | movila banului
# Processing Record 17 of Set 6 | ambilobe
# Processing Record 18 of Set 6 | camargo
# Processing Record 19 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 20 of Set 6 | sibu
# Processing Record 21 of Set 6 | pinar del rio
# Processing Record 22 of Set 6 | ostersund
# Processing Record 23 of Set 6 | vardo
# Processing Record 24 of Set 6 | ponta do sol
# Processing Record 25 of Set 6 | pontianak
# Processing Record 26 of Set 6 | sobolevo
# Processing Record 27 of Set 6 | ochakiv
# Processing Record 28 of Set 6 | broken hill
# Processing Record 29 of Set 6 | maungatapere
# Processing Record 30 of Set 6 | bonfim
# Processing Record 31 of Set 6 | monmouth
# Processing Record 32 of Set 6 | mukhen
# Processing Record 33 of Set 6 | salalah
# Processing Record 34 of Set 6 | westport
# Processing Record 35 of Set 6 | havoysund
# Processing Record 36 of Set 6 | jizan
# Processing Record 37 of Set 6 | andrelandia
# Processing Record 38 of Set 6 | rio grande
# Processing Record 39 of Set 6 | libreville
# Processing Record 40 of Set 6 | dekoa
# City not found. Skipping...
# Processing Record 41 of Set 6 | pilar
# Processing Record 42 of Set 6 | kysyl-syr
# Processing Record 43 of Set 6 | kaitangata
# Processing Record 44 of Set 6 | bilibino
# Processing Record 45 of Set 6 | pasighat
# Processing Record 46 of Set 6 | balkanabat
# Processing Record 47 of Set 6 | katghora
# Processing Record 48 of Set 6 | sanok
# Processing Record 49 of Set 6 | mtsensk
# Processing Record 50 of Set 6 | lima
# Processing Record 1 of Set 7 | zuenoula
# Processing Record 2 of Set 7 | arlit
# Processing Record 3 of Set 7 | sault sainte marie
# Processing Record 4 of Set 7 | kholtoson
# Processing Record 5 of Set 7 | ancud
# Processing Record 6 of Set 7 | djenne
# Processing Record 7 of Set 7 | abu samrah
# Processing Record 8 of Set 7 | camacha
# Processing Record 9 of Set 7 | salina cruz
# Processing Record 10 of Set 7 | geraldton
# Processing Record 11 of Set 7 | san quintin
# Processing Record 12 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 7 | nandu
# Processing Record 14 of Set 7 | kaifeng
# Processing Record 15 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 16 of Set 7 | taoudenni
# Processing Record 17 of Set 7 | kroya
# Processing Record 18 of Set 7 | betamcherla
# Processing Record 19 of Set 7 | babanusah
# City not found. Skipping...
# Processing Record 20 of Set 7 | west odessa
# Processing Record 21 of Set 7 | hangu
# Processing Record 22 of Set 7 | jacareacanga
# Processing Record 23 of Set 7 | ahuimanu
# Processing Record 24 of Set 7 | shimoda
# Processing Record 25 of Set 7 | ifakara
# Processing Record 26 of Set 7 | yulara
# Processing Record 27 of Set 7 | cidreira
# Processing Record 28 of Set 7 | trinidad
# Processing Record 29 of Set 7 | carinhanha
# Processing Record 30 of Set 7 | poum
# Processing Record 31 of Set 7 | jinchang
# Processing Record 32 of Set 7 | barranca
# Processing Record 33 of Set 7 | naugarzan
# City not found. Skipping...
# Processing Record 34 of Set 7 | port-gentil
# Processing Record 35 of Set 7 | dingle
# Processing Record 36 of Set 7 | ormara
# Processing Record 37 of Set 7 | porto novo
# Processing Record 38 of Set 7 | zalantun
# Processing Record 39 of Set 7 | burnie
# Processing Record 40 of Set 7 | odesskoye
# Processing Record 41 of Set 7 | norman wells
# Processing Record 42 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 43 of Set 7 | ostrovskoye
# Processing Record 44 of Set 7 | tomorkeny
# Processing Record 45 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 46 of Set 7 | hami
# Processing Record 47 of Set 7 | cayenne
# Processing Record 48 of Set 7 | bay-khaak
# Processing Record 49 of Set 7 | kushima
# Processing Record 50 of Set 7 | katsuura
# Processing Record 1 of Set 8 | coos bay
# Processing Record 2 of Set 8 | jasper
# Processing Record 3 of Set 8 | rocha
# Processing Record 4 of Set 8 | denton
# Processing Record 5 of Set 8 | coquimbo
# Processing Record 6 of Set 8 | tecpan
# Processing Record 7 of Set 8 | imeni poliny osipenko
# Processing Record 8 of Set 8 | jalu
# Processing Record 9 of Set 8 | phan rang
# City not found. Skipping...
# Processing Record 10 of Set 8 | kenai
# Processing Record 11 of Set 8 | huixtla
# Processing Record 12 of Set 8 | staraya mayna
# Processing Record 13 of Set 8 | sao gabriel da cachoeira
# Processing Record 14 of Set 8 | saint-pierre
# Processing Record 15 of Set 8 | atbasar
# Processing Record 16 of Set 8 | macia
# Processing Record 17 of Set 8 | artyk
# City not found. Skipping...
# Processing Record 18 of Set 8 | seydi
# Processing Record 19 of Set 8 | vaitape
# Processing Record 20 of Set 8 | mehamn
# Processing Record 21 of Set 8 | kesennuma
# City not found. Skipping...
# Processing Record 22 of Set 8 | uuemoisa
# Processing Record 23 of Set 8 | richards bay
# Processing Record 24 of Set 8 | mareeba
# Processing Record 25 of Set 8 | liberia
# Processing Record 26 of Set 8 | puerto rondon
# Processing Record 27 of Set 8 | longyearbyen
# Processing Record 28 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 29 of Set 8 | araouane
# Processing Record 30 of Set 8 | vestmannaeyjar
# Processing Record 31 of Set 8 | voh
# Processing Record 32 of Set 8 | bardiyah
# Processing Record 33 of Set 8 | kloulklubed
# Processing Record 34 of Set 8 | polunochnoye
# Processing Record 35 of Set 8 | auki
# Processing Record 36 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 37 of Set 8 | cockburn town
# Processing Record 38 of Set 8 | banjar
# Processing Record 39 of Set 8 | khatanga
# Processing Record 40 of Set 8 | dicabisagan
# Processing Record 41 of Set 8 | banda aceh
# Processing Record 42 of Set 8 | mecca
# Processing Record 43 of Set 8 | aklavik
# Processing Record 44 of Set 8 | port hedland
# Processing Record 45 of Set 8 | pressbaum
# Processing Record 46 of Set 8 | nome
# Processing Record 47 of Set 8 | mtambile
# Processing Record 48 of Set 8 | milkovo
# Processing Record 49 of Set 8 | okmulgee
# Processing Record 50 of Set 8 | waingapu
# Processing Record 1 of Set 9 | suez
# Processing Record 2 of Set 9 | kandrian
# Processing Record 3 of Set 9 | torbat-e jam
# Processing Record 4 of Set 9 | kirakira
# Processing Record 5 of Set 9 | esperance
# Processing Record 6 of Set 9 | tikhvin
# Processing Record 7 of Set 9 | tlahualilo
# City not found. Skipping...
# Processing Record 8 of Set 9 | namibe
# Processing Record 9 of Set 9 | moussoro
# Processing Record 10 of Set 9 | bernardino de campos
# Processing Record 11 of Set 9 | grindavik
# Processing Record 12 of Set 9 | bela
# Processing Record 13 of Set 9 | yangambi
# Processing Record 14 of Set 9 | aykhal
# Processing Record 15 of Set 9 | touros
# Processing Record 16 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 17 of Set 9 | coihaique
# Processing Record 18 of Set 9 | morecambe
# Processing Record 19 of Set 9 | tanete
# Processing Record 20 of Set 9 | bongor
# Processing Record 21 of Set 9 | kudahuvadhoo
# Processing Record 22 of Set 9 | bam
# Processing Record 23 of Set 9 | ranfurly
# Processing Record 24 of Set 9 | acapulco
# Processing Record 25 of Set 9 | quatre cocos
# Processing Record 26 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 27 of Set 9 | candolim
# Processing Record 28 of Set 9 | hachinohe
# Processing Record 29 of Set 9 | litoral del san juan
# City not found. Skipping...
# Processing Record 30 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 31 of Set 9 | walla walla
# Processing Record 32 of Set 9 | chapais
# Processing Record 33 of Set 9 | iqaluit
# Processing Record 34 of Set 9 | kodiak
# Processing Record 35 of Set 9 | luebo
# Processing Record 36 of Set 9 | gudalur
# Processing Record 37 of Set 9 | nanortalik
# Processing Record 38 of Set 9 | berlevag
# Processing Record 39 of Set 9 | canutama
# Processing Record 40 of Set 9 | isangel
# Processing Record 41 of Set 9 | san borja
# Processing Record 42 of Set 9 | urusha
# Processing Record 43 of Set 9 | davila
# Processing Record 44 of Set 9 | amahai
# Processing Record 45 of Set 9 | kruisfontein
# Processing Record 46 of Set 9 | sungaipenuh
# Processing Record 47 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 48 of Set 9 | marysville
# Processing Record 49 of Set 9 | ketchikan
# Processing Record 50 of Set 9 | ilulissat
# Processing Record 1 of Set 10 | sioux lookout
# Processing Record 2 of Set 10 | sakakah
# Processing Record 3 of Set 10 | vostok
# Processing Record 4 of Set 10 | saldanha
# Processing Record 5 of Set 10 | oistins
# Processing Record 6 of Set 10 | mount isa
# Processing Record 7 of Set 10 | mendahara
# City not found. Skipping...
# Processing Record 8 of Set 10 | xingcheng
# Processing Record 9 of Set 10 | inuvik
# Processing Record 10 of Set 10 | sur
# Processing Record 11 of Set 10 | angoche
# Processing Record 12 of Set 10 | komsomolskiy
# Processing Record 13 of Set 10 | codrington
# Processing Record 14 of Set 10 | lavrentiya
# Processing Record 15 of Set 10 | veinticinco de mayo
# Processing Record 16 of Set 10 | victoria
# Processing Record 17 of Set 10 | jabiru
# City not found. Skipping...
# Processing Record 18 of Set 10 | tual
# Processing Record 19 of Set 10 | misratah
# Processing Record 20 of Set 10 | sulangan
# Processing Record 21 of Set 10 | ginda
# Processing Record 22 of Set 10 | nouadhibou
# Processing Record 23 of Set 10 | mananara
# Processing Record 24 of Set 10 | san martin
# Processing Record 25 of Set 10 | niny
# Processing Record 26 of Set 10 | alappuzha
# Processing Record 27 of Set 10 | erzin
# Processing Record 28 of Set 10 | saint-georges
# Processing Record 29 of Set 10 | sovetskiy
# Processing Record 30 of Set 10 | dunedin
# Processing Record 31 of Set 10 | tadine
# Processing Record 32 of Set 10 | bardsir
# Processing Record 33 of Set 10 | susanville
# Processing Record 34 of Set 10 | nhulunbuy
# Processing Record 35 of Set 10 | batagay-alyta
# Processing Record 36 of Set 10 | starogard gdanski
# Processing Record 37 of Set 10 | kananga
# Processing Record 38 of Set 10 | denia
# Processing Record 39 of Set 10 | bahia honda
# Processing Record 40 of Set 10 | hecun
# Processing Record 41 of Set 10 | saint-nazaire
# Processing Record 42 of Set 10 | ponta delgada
# Processing Record 43 of Set 10 | roswell
# Processing Record 44 of Set 10 | mega
# Processing Record 45 of Set 10 | innisfail
# Processing Record 46 of Set 10 | rajula
# Processing Record 47 of Set 10 | batemans bay
# Processing Record 48 of Set 10 | dali
# Processing Record 49 of Set 10 | la orilla
# Processing Record 50 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 1 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 2 of Set 11 | guadalajara
# Processing Record 3 of Set 11 | fort nelson
# Processing Record 4 of Set 11 | kavieng
# Processing Record 5 of Set 11 | chicama
# Processing Record 6 of Set 11 | gizo
# Processing Record 7 of Set 11 | klyuchi
# Processing Record 8 of Set 11 | mandalgovi
# Processing Record 9 of Set 11 | filadelfia
# Processing Record 10 of Set 11 | ishigaki
# Processing Record 11 of Set 11 | brighton
# Processing Record 12 of Set 11 | grand-lahou
# Processing Record 13 of Set 11 | opportunity
# Processing Record 14 of Set 11 | fairbanks
# Processing Record 15 of Set 11 | maumere
# Processing Record 16 of Set 11 | udachnyy
# Processing Record 17 of Set 11 | aswan
# Processing Record 18 of Set 11 | superior
# Processing Record 19 of Set 11 | portland
# Processing Record 20 of Set 11 | kismayo
# Processing Record 21 of Set 11 | henties bay
# Processing Record 22 of Set 11 | russell
# Processing Record 23 of Set 11 | port augusta
# Processing Record 24 of Set 11 | zhangjiakou
# Processing Record 25 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 26 of Set 11 | remedios
# Processing Record 27 of Set 11 | nemuro
# Processing Record 28 of Set 11 | bredy
# Processing Record 29 of Set 11 | rosetown
# Processing Record 30 of Set 11 | yanan
# City not found. Skipping...
# Processing Record 31 of Set 11 | nantai
# Processing Record 32 of Set 11 | eureka
# Processing Record 33 of Set 11 | kuytun
# Processing Record 34 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 35 of Set 11 | north platte
# Processing Record 36 of Set 11 | preobrazheniye
# Processing Record 37 of Set 11 | tilichiki
# Processing Record 38 of Set 11 | xichang
# Processing Record 39 of Set 11 | noumea
# Processing Record 40 of Set 11 | kirkkonummi
# Processing Record 41 of Set 11 | tarabha
# Processing Record 42 of Set 11 | tautira
# Processing Record 43 of Set 11 | paredon
# Processing Record 44 of Set 11 | kutum
# Processing Record 45 of Set 11 | dawei
# Processing Record 46 of Set 11 | toamasina
# Processing Record 47 of Set 11 | ust-kulom
# Processing Record 48 of Set 11 | inndyr
# Processing Record 49 of Set 11 | cap-aux-meules
# Processing Record 50 of Set 11 | aksu
# Processing Record 1 of Set 12 | kahului
# Processing Record 2 of Set 12 | hokitika
# Processing Record 3 of Set 12 | preveza
# Processing Record 4 of Set 12 | nantucket
# Processing Record 5 of Set 12 | kyabe
# Processing Record 6 of Set 12 | asau
# Processing Record 7 of Set 12 | vanimo
# Processing Record 8 of Set 12 | tessalit
# Processing Record 9 of Set 12 | jiaozuo
# Processing Record 10 of Set 12 | san policarpo
# Processing Record 11 of Set 12 | iranshahr
# Processing Record 12 of Set 12 | luanda
# Processing Record 13 of Set 12 | bacolod
# Processing Record 14 of Set 12 | muroto
# Processing Record 15 of Set 12 | itoman
# Processing Record 16 of Set 12 | matara
# Processing Record 17 of Set 12 | marawi
# Processing Record 18 of Set 12 | walvis bay
# Processing Record 19 of Set 12 | sabancuy
# Processing Record 20 of Set 12 | kemijarvi
# Processing Record 21 of Set 12 | puerto colombia
# Processing Record 22 of Set 12 | sao joao da barra
# Processing Record 23 of Set 12 | kaeo
# Processing Record 24 of Set 12 | pimentel
# Processing Record 25 of Set 12 | suffolk
# Processing Record 26 of Set 12 | koslan
# Processing Record 27 of Set 12 | san patricio
# Processing Record 28 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 12 | khanpur
# Processing Record 30 of Set 12 | the valley
# Processing Record 31 of Set 12 | xiangdong
# City not found. Skipping...
# Processing Record 32 of Set 12 | sevenoaks
# Processing Record 33 of Set 12 | bossangoa
# Processing Record 34 of Set 12 | teknaf
# Processing Record 35 of Set 12 | praia da vitoria
# Processing Record 36 of Set 12 | chaohu
# Processing Record 37 of Set 12 | vilyuysk
# Processing Record 38 of Set 12 | gueret
# Processing Record 39 of Set 12 | marondera
# Processing Record 40 of Set 12 | rio bueno
# Processing Record 41 of Set 12 | mahajanga
# Processing Record 42 of Set 12 | saint pete beach
# Processing Record 43 of Set 12 | non sang
# Processing Record 44 of Set 12 | yerbogachen
# Processing Record 45 of Set 12 | conde
# Processing Record 46 of Set 12 | lake charles
# Processing Record 47 of Set 12 | rawson
# Processing Record 48 of Set 12 | afmadu
# City not found. Skipping...
# Processing Record 49 of Set 12 | tanabe
# Processing Record 50 of Set 12 | carupano
# Processing Record 1 of Set 13 | clarence town
# Processing Record 2 of Set 13 | katsiveli
# City not found. Skipping...
# Processing Record 3 of Set 13 | laurel
# Processing Record 4 of Set 13 | velikiy ustyug
# Processing Record 5 of Set 13 | shambu
# Processing Record 6 of Set 13 | langxiang
# Processing Record 7 of Set 13 | bubaque
# Processing Record 8 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 9 of Set 13 | durango
# Processing Record 10 of Set 13 | aasiaat
# Processing Record 11 of Set 13 | kamenka
# Processing Record 12 of Set 13 | kresek
# Processing Record 13 of Set 13 | buariki
# City not found. Skipping...
# Processing Record 14 of Set 13 | altay
# Processing Record 15 of Set 13 | pisco
# Processing Record 16 of Set 13 | hailun
# Processing Record 17 of Set 13 | podporozhye
# Processing Record 18 of Set 13 | hualmay
# Processing Record 19 of Set 13 | yeppoon
# Processing Record 20 of Set 13 | cerro largo
# Processing Record 21 of Set 13 | najran
# Processing Record 22 of Set 13 | zhoucheng
# Processing Record 23 of Set 13 | alekseyevsk
# Processing Record 24 of Set 13 | praia
# Processing Record 25 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 26 of Set 13 | pemba
# Processing Record 27 of Set 13 | severnyy
# Processing Record 28 of Set 13 | vyazemskiy
# Processing Record 29 of Set 13 | scarborough
# Processing Record 30 of Set 13 | tambura
# Processing Record 31 of Set 13 | chumikan
# Processing Record 32 of Set 13 | ontario
# Processing Record 33 of Set 13 | jumla
# Processing Record 34 of Set 13 | maragogi
# Processing Record 35 of Set 13 | tubruq
# City not found. Skipping...
# Processing Record 36 of Set 13 | ocean city
# Processing Record 37 of Set 13 | santiago
# Processing Record 38 of Set 13 | lochgilphead
# Processing Record 39 of Set 13 | ziniare
# Processing Record 40 of Set 13 | wadi maliz
# Processing Record 41 of Set 13 | wete
# Processing Record 42 of Set 13 | laguna
# Processing Record 43 of Set 13 | boulder
# Processing Record 44 of Set 13 | aviles
# Processing Record 45 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 46 of Set 13 | sladkovo
# Processing Record 47 of Set 13 | otofuke
# Processing Record 48 of Set 13 | matadi
# Processing Record 49 of Set 13 | siverek
# Processing Record 50 of Set 13 | jamame
# Processing Record 1 of Set 14 | sobradinho
# Processing Record 2 of Set 14 | samarai
# Processing Record 3 of Set 14 | lebanon
# Processing Record 4 of Set 14 | santana do livramento
# Processing Record 5 of Set 14 | mantua
# Processing Record 6 of Set 14 | amalapuram
# Processing Record 7 of Set 14 | mildura
# Processing Record 8 of Set 14 | krasnoselkup
# Processing Record 9 of Set 14 | phan thiet
# Processing Record 10 of Set 14 | san antonio
# Processing Record 11 of Set 14 | piacabucu
# Processing Record 12 of Set 14 | padang
# Processing Record 13 of Set 14 | bullingen
# City not found. Skipping...
# Processing Record 14 of Set 14 | abu kamal
# Processing Record 15 of Set 14 | luba
# Processing Record 16 of Set 14 | foumban
# Processing Record 17 of Set 14 | liwale
# Processing Record 18 of Set 14 | kiruna
# Processing Record 19 of Set 14 | bulgan
# Processing Record 20 of Set 14 | albanel
# Processing Record 21 of Set 14 | yabrud
# Processing Record 22 of Set 14 | inirida
# Processing Record 23 of Set 14 | quang ngai
# Processing Record 24 of Set 14 | chernyshevskiy
# Processing Record 25 of Set 14 | sao filipe
# Processing Record 26 of Set 14 | zelenogorskiy
# Processing Record 27 of Set 14 | qandala
# Processing Record 28 of Set 14 | sabang
# Processing Record 29 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 30 of Set 14 | manta
# Processing Record 31 of Set 14 | cabedelo
# Processing Record 32 of Set 14 | dungarvan
# Processing Record 33 of Set 14 | artyom
# Processing Record 34 of Set 14 | koygorodok
# Processing Record 35 of Set 14 | berkak
# Processing Record 36 of Set 14 | alyangula
# Processing Record 37 of Set 14 | banfora
# Processing Record 38 of Set 14 | tiznit
# Processing Record 39 of Set 14 | vallenar
# Processing Record 40 of Set 14 | dong xoai
# Processing Record 41 of Set 14 | burica
# City not found. Skipping...
# Processing Record 42 of Set 14 | kjollefjord
# Processing Record 43 of Set 14 | ito
# Processing Record 44 of Set 14 | jibuti
# Processing Record 45 of Set 14 | basco
# Processing Record 46 of Set 14 | lieksa
# Processing Record 47 of Set 14 | oksfjord
# Processing Record 48 of Set 14 | manokwari
# Processing Record 49 of Set 14 | abrego
# Processing Record 50 of Set 14 | yendi
# Processing Record 1 of Set 15 | wanning
# Processing Record 2 of Set 15 | khartoum
# Processing Record 3 of Set 15 | kavant
# City not found. Skipping...
# Processing Record 4 of Set 15 | serabu
# Processing Record 5 of Set 15 | alice
# Processing Record 6 of Set 15 | otane
# Processing Record 7 of Set 15 | boyuibe
# Processing Record 8 of Set 15 | harlingen
# Processing Record 9 of Set 15 | ljungby
# Processing Record 10 of Set 15 | chara
# Processing Record 11 of Set 15 | avila
# Processing Record 12 of Set 15 | thanh hoa
# Processing Record 13 of Set 15 | pointe-noire
# Processing Record 14 of Set 15 | longyan
# Processing Record 15 of Set 15 | namatanai
# Processing Record 16 of Set 15 | magdagachi
# Processing Record 17 of Set 15 | sakaiminato
# Processing Record 18 of Set 15 | teya
# Processing Record 19 of Set 15 | nelson bay
# Processing Record 20 of Set 15 | boa vista
# Processing Record 21 of Set 15 | moron
# Processing Record 22 of Set 15 | qabis
# City not found. Skipping...
# Processing Record 23 of Set 15 | starosubkhangulovo
# Processing Record 24 of Set 15 | krym
# Processing Record 25 of Set 15 | kyshtovka
# Processing Record 26 of Set 15 | romny
# Processing Record 27 of Set 15 | skibbereen
# Processing Record 28 of Set 15 | huancavelica
# Processing Record 29 of Set 15 | houma
# Processing Record 30 of Set 15 | faya
# Processing Record 31 of Set 15 | ilula
# Processing Record 32 of Set 15 | kissamos
# Processing Record 33 of Set 15 | gopalur
# Processing Record 34 of Set 15 | mwene-ditu
# Processing Record 35 of Set 15 | nokaneng
# Processing Record 36 of Set 15 | svetlogorsk
# Processing Record 37 of Set 15 | bakchar
# Processing Record 38 of Set 15 | farafangana
# Processing Record 39 of Set 15 | katherine
# Processing Record 40 of Set 15 | sao desiderio
# Processing Record 41 of Set 15 | pullman
# Processing Record 42 of Set 15 | mackay
# Processing Record 43 of Set 15 | kitui
# Processing Record 44 of Set 15 | yelnya
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 684

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Rikitea -23.1203 -134.9692     73.92        75          29
# 1      Tasiilaq  65.6145  -37.6368     53.76        76          24
# 2      Tateyama  34.9833  139.8667     80.62        85          29
# 3       Ushuaia -54.8000  -68.3000     49.62        75          75
# 4        Ossora  59.2353  163.0719     48.38        92         100
# 5        Omboue  -1.5746    9.2618     76.30        80          55
# 6  Tirat Karmel  32.7617   34.9719     85.55        48           0
# 7   Tuktoyaktuk  69.4541 -133.0374     59.00        77          75
# 8        Mutoko -17.3970   32.2268     52.20        49           0
# 9        Hobart -42.8794  147.3294     55.26        59          40
#
#    Wind Speed Country                 Date   Current Description
# 0       18.16      PF  2021-08-05 19:40:32      scattered clouds
# 1        2.19      GL  2021-08-05 19:39:36            few clouds
# 2        8.55      JP  2021-08-05 19:42:58      scattered clouds
# 3       33.38      AR  2021-08-05 19:38:48  heavy intensity rain
# 4       11.61      RU  2021-08-05 19:42:22         moderate rain
# 5        8.66      GA  2021-08-05 19:42:59         broken clouds
# 6        1.14      IL  2021-08-05 19:42:59             clear sky
# 7        8.05      CA  2021-08-05 19:39:19         broken clouds
# 8        3.00      ZW  2021-08-05 19:42:59             clear sky
# 9        5.01      AU  2021-08-05 19:39:47      scattered clouds

# %%
# Set nr eorders of the database
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed",
                    "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Rikitea      PF -23.1203 -134.9692     73.92        75          29
# 1      Tasiilaq      GL  65.6145  -37.6368     53.76        76          24
# 2      Tateyama      JP  34.9833  139.8667     80.62        85          29
# 3       Ushuaia      AR -54.8000  -68.3000     49.62        75          75
# 4        Ossora      RU  59.2353  163.0719     48.38        92         100
# 5        Omboue      GA  -1.5746    9.2618     76.30        80          55
# 6  Tirat Karmel      IL  32.7617   34.9719     85.55        48           0
# 7   Tuktoyaktuk      CA  69.4541 -133.0374     59.00        77          75
# 8        Mutoko      ZW -17.3970   32.2268     52.20        49           0
# 9        Hobart      AU -42.8794  147.3294     55.26        59          40
#
#    Wind Speed   Current Description
# 0       18.16      scattered clouds
# 1        2.19            few clouds
# 2        8.55      scattered clouds
# 3       33.38  heavy intensity rain
# 4       11.61         moderate rain
# 5        8.66         broken clouds
# 6        1.14             clear sky
# 7        8.05         broken clouds
# 8        3.00             clear sky
# 9        5.01      scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "weather_database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
